# %% [markdown]
# # Import Statements

# %%
import requests
from requests_oauthlib import OAuth1
import os, json
from time import sleep

# %% [markdown]
# # Using requests to get data in Badges

# %%
path = 'Badges'
if not os.path.exists(path):
    os.makedirs(path)

for i in range(1,100):        
    url = 'https://api.stackexchange.com/2.2/badges?page='+str(i)+'&pagesize=100&order=desc&sort=name&site=stackoverflow&key=IwwP2VRDlnaZ82DdajaXFQ(('
    response = requests.get(url)
    response = response.json()
    print(response)
    with open('Badges/'+str(i)+'.json', 'w') as f:
         json.dump(response, f)
# Out:
# {'quota_remaining': 9971, 'items': [{'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4600, 'name': 'zxing', 'link': 'http://stackoverflow.com/badges/4600/zxing'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 1710, 'name': 'zxing', 'link': 'http://stackoverflow.com/badges/1710/zxing'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5743, 'name': 'zurb-foundation', 'link': 'http://stackoverflow.com/badges/5743/zurb-foundation'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 1786, 'name': 'zsh', 'link': 'http://stackoverflow.com/badges/1786/zsh'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 2984, 'name': 'zope', 'link': 'http://stackoverflow.com/badges/2984/zope'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 1201, 'name': 'zope', 'link': 'http://stackoverflow.com/badges/1201/zope'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4561, 'name': 'zookeeper', 'link': 'http://stackoverflow.com/badges/4561/zookeeper'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6344, 'name': 'zoo', 'link': 'http://stackoverflow.com/badges/6344/zoo'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2391, 'name': 'zoo', 'link': 'http://stackoverflow.com/badges/2391/zoo'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3294, 'name': 'zodb', 'link': 'http://stackoverflow.com/badges/3294/zodb'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 6091, 'name': 'zlib', 'link': 'http://stackoverflow.com/badges/6091/zlib'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5256, 'name': 'zlib', 'link': 'http://stackoverflow.com/badges/5256/zlib'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2712, 'name': 'zlib', 'link': 'http://stackoverflow.com/badges/2712/zlib'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 5411, 'name': 'zk', 'link': 'http://stackoverflow.com/badges/5411/zk'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 4285, 'name': 'zip', 'link': 'http://stackoverflow.com/badges/4285/zip'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 613, 'name': 'zip', 'link': 'http://stackoverflow.com/badges/613/zip'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6021, 'name': 'zingchart', 'link': 'http://stackoverflow.com/badges/6021/zingchart'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6200, 'name': 'zeromq', 'link': 'http://stackoverflow.com/badges/6200/zeromq'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 2617, 'name': 'zeromq', 'link': 'http://stackoverflow.com/badges/2617/zeromq'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5780, 'name': 'zend-framework2', 'link': 'http://stackoverflow.com/badges/5780/zend-framework2'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 5, 'badge_id': 3215, 'name': 'zend-framework2', 'link': 'http://stackoverflow.com/badges/3215/zend-framework2'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 20, 'badge_id': 2529, 'name': 'zend-framework2', 'link': 'http://stackoverflow.com/badges/2529/zend-framework2'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 3698, 'name': 'zend-framework', 'link': 'http://stackoverflow.com/badges/3698/zend-framework'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 13, 'badge_id': 910, 'name': 'zend-framework', 'link': 'http://stackoverflow.com/badges/910/zend-framework'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 59, 'badge_id': 357, 'name': 'zend-framework', 'link': 'http://stackoverflow.com/badges/357/zend-framework'}, {'badge ...
# {'quota_remaining': 9970, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 4251, 'name': 'xml-namespaces', 'link': 'http://stackoverflow.com/badges/4251/xml-namespaces'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 7, 'badge_id': 3002, 'name': 'xmlhttprequest', 'link': 'http://stackoverflow.com/badges/3002/xmlhttprequest'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1549, 'name': 'xmldocument', 'link': 'http://stackoverflow.com/badges/1549/xmldocument'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2855, 'name': 'xml-deserialization', 'link': 'http://stackoverflow.com/badges/2855/xml-deserialization'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 19, 'badge_id': 822, 'name': 'xml', 'link': 'http://stackoverflow.com/badges/822/xml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 276, 'badge_id': 328, 'name': 'xml', 'link': 'http://stackoverflow.com/badges/328/xml'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 54, 'badge_id': 105, 'name': 'xml', 'link': 'http://stackoverflow.com/badges/105/xml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5127, 'name': 'xlsxwriter', 'link': 'http://stackoverflow.com/badges/5127/xlsxwriter'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 5423, 'name': 'xlsx', 'link': 'http://stackoverflow.com/badges/5423/xlsx'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4992, 'name': 'xls', 'link': 'http://stackoverflow.com/badges/4992/xls'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2509, 'name': 'xlrd', 'link': 'http://stackoverflow.com/badges/2509/xlrd'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6298, 'name': 'xlib', 'link': 'http://stackoverflow.com/badges/6298/xlib'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 3561, 'name': 'xjc', 'link': 'http://stackoverflow.com/badges/3561/xjc'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4679, 'name': 'xib', 'link': 'http://stackoverflow.com/badges/4679/xib'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 1332, 'name': 'xhtml', 'link': 'http://stackoverflow.com/badges/1332/xhtml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 16, 'badge_id': 567, 'name': 'xhtml', 'link': 'http://stackoverflow.com/badges/567/xhtml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2664, 'name': 'xforms', 'link': 'http://stackoverflow.com/badges/2664/xforms'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2421, 'name': 'xelement', 'link': 'http://stackoverflow.com/badges/2421/xelement'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2484, 'name': 'xdebug', 'link': 'http://stackoverflow.com/badges/2484/xdebug'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6417, 'name': 'xcode-ui-testing', 'link': 'http://stackoverflow.com/badges/6417/xcode-ui-testing'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5593, 'name': 'xcode-ui-testing', 'link': 'http://stackoverflow.com/badges/5593/xcode-ui-testing'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 6081, 'name': 'xcode7', 'link': 'http://stackoverflow.com/badges/6081/xcode7'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6144, 'name': 'xcode6', 'link': 'http://stackoverflow.com/badges/6144/xcode6'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 8, 'badge_id': 4541, 'name': 'xcode6', 'link': 'http://stackoverflow.com/badges/4541/xcode6'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3345, 'name': 'xcode5', 'link': 'http://stackoverflow.com/badges/3345/xcode5'}, { ...
# {'quota_remaining': 9970, 'items': [{'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 3, 'badge_id': 2944, 'name': 'wix', 'link': 'http://stackoverflow.com/badges/2944/wix'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 9, 'badge_id': 1086, 'name': 'wix', 'link': 'http://stackoverflow.com/badges/1086/wix'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 20, 'badge_id': 599, 'name': 'wix', 'link': 'http://stackoverflow.com/badges/599/wix'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4389, 'name': 'with-statement', 'link': 'http://stackoverflow.com/badges/4389/with-statement'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4872, 'name': 'wireshark', 'link': 'http://stackoverflow.com/badges/4872/wireshark'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 4874, 'name': 'win-universal-app', 'link': 'http://stackoverflow.com/badges/4874/win-universal-app'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2559, 'name': 'winsock', 'link': 'http://stackoverflow.com/badges/2559/winsock'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6203, 'name': 'winscp-net', 'link': 'http://stackoverflow.com/badges/6203/winscp-net'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4571, 'name': 'winscp', 'link': 'http://stackoverflow.com/badges/4571/winscp'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 3932, 'name': 'winrt-xaml', 'link': 'http://stackoverflow.com/badges/3932/winrt-xaml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 2437, 'name': 'winrt-xaml', 'link': 'http://stackoverflow.com/badges/2437/winrt-xaml'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2655, 'name': 'winjs', 'link': 'http://stackoverflow.com/badges/2655/winjs'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 257, 'badge_id': 364, 'name': 'winforms', 'link': 'http://stackoverflow.com/badges/364/winforms'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 11, 'badge_id': 224, 'name': 'winforms', 'link': 'http://stackoverflow.com/badges/224/winforms'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 32, 'badge_id': 149, 'name': 'winforms', 'link': 'http://stackoverflow.com/badges/149/winforms'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 3035, 'name': 'windows-xp', 'link': 'http://stackoverflow.com/badges/3035/windows-xp'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5767, 'name': 'windows-store-apps', 'link': 'http://stackoverflow.com/badges/5767/windows-store-apps'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 3330, 'name': 'windows-store-apps', 'link': 'http://stackoverflow.com/badges/3330/windows-store-apps'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3616, 'name': 'windows-services', 'link': 'http://stackoverflow.com/badges/3616/windows-services'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 612, 'name': 'windows-services', 'link': 'http://stackoverflow.com/badges/612/windows-services'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 4244, 'name': 'windows-runtime', 'link': 'http://stackoverflow.com/badges/4244/windows-runtime'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 2720, 'name': 'windows-runtime', 'link': 'http://stackoverflow.com/badges/2720/windows-runtime'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 20, 'badge_id': 2411, 'name': 'windows-runtime', 'link': 'http://stackoverflow.com/badges/2411/windows-runtime'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4669, 'name': 'windows-phone-8.1', 'link': 'http://stackoverflow.com/badges/4669/windows-phone-8- ...
# {'quota_remaining': 9970, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 683, 'name': 'weblogic', 'link': 'http://stackoverflow.com/badges/683/weblogic'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2147, 'name': 'webkit', 'link': 'http://stackoverflow.com/badges/2147/webkit'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2327, 'name': 'webgrid', 'link': 'http://stackoverflow.com/badges/2327/webgrid'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5928, 'name': 'webgl', 'link': 'http://stackoverflow.com/badges/5928/webgl'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 3, 'badge_id': 3750, 'name': 'webgl', 'link': 'http://stackoverflow.com/badges/3750/webgl'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 2009, 'name': 'webgl', 'link': 'http://stackoverflow.com/badges/2009/webgl'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 6, 'badge_id': 3227, 'name': 'webforms', 'link': 'http://stackoverflow.com/badges/3227/webforms'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 3911, 'name': 'webdriver', 'link': 'http://stackoverflow.com/badges/3911/webdriver'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 18, 'badge_id': 1981, 'name': 'webdriver', 'link': 'http://stackoverflow.com/badges/1981/webdriver'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5343, 'name': 'webdeploy', 'link': 'http://stackoverflow.com/badges/5343/webdeploy'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3903, 'name': 'web-crawler', 'link': 'http://stackoverflow.com/badges/3903/web-crawler'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 7, 'badge_id': 2151, 'name': 'web-config', 'link': 'http://stackoverflow.com/badges/2151/web-config'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 4565, 'name': 'web-component', 'link': 'http://stackoverflow.com/badges/4565/web-component'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2906, 'name': 'webclient', 'link': 'http://stackoverflow.com/badges/2906/webclient'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6026, 'name': 'webcam', 'link': 'http://stackoverflow.com/badges/6026/webcam'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5685, 'name': 'webbrowser-control', 'link': 'http://stackoverflow.com/badges/5685/webbrowser-control'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 3184, 'name': 'webbrowser-control', 'link': 'http://stackoverflow.com/badges/3184/webbrowser-control'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5028, 'name': 'web-audio', 'link': 'http://stackoverflow.com/badges/5028/web-audio'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 3598, 'name': 'web-audio', 'link': 'http://stackoverflow.com/badges/3598/web-audio'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 2525, 'name': 'web-applications', 'link': 'http://stackoverflow.com/badges/2525/web-applications'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 13, 'badge_id': 716, 'name': 'web-applications', 'link': 'http://stackoverflow.com/badges/716/web-applications'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5486, 'name': 'web-api', 'link': 'http://stackoverflow.com/badges/5486/web-api'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 6085, 'name': 'web2py', 'link': 'http://stackoverflow.com/badges/6085/web2py'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3033, 'name': 'web2py', 'link': 'http://stackoverflow.com/badges/3033/web2py'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, ...
# {'quota_remaining': 9970, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3229, 'name': 'virtualenv', 'link': 'http://stackoverflow.com/badges/3229/virtualenv'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 4757, 'name': 'virtualbox', 'link': 'http://stackoverflow.com/badges/4757/virtualbox'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 1435, 'name': 'virtual', 'link': 'http://stackoverflow.com/badges/1435/virtual'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5558, 'name': 'vim-syntax-highlighting', 'link': 'http://stackoverflow.com/badges/5558/vim-syntax-highlighting'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 3048, 'name': 'vim-plugin', 'link': 'http://stackoverflow.com/badges/3048/vim-plugin'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6407, 'name': 'vimeo-api', 'link': 'http://stackoverflow.com/badges/6407/vimeo-api'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5841, 'name': 'vimeo', 'link': 'http://stackoverflow.com/badges/5841/vimeo'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 13, 'badge_id': 2269, 'name': 'vim', 'link': 'http://stackoverflow.com/badges/2269/vim'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 27, 'badge_id': 831, 'name': 'vim', 'link': 'http://stackoverflow.com/badges/831/vim'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 141, 'badge_id': 303, 'name': 'vim', 'link': 'http://stackoverflow.com/badges/303/vim'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4933, 'name': 'view-scope', 'link': 'http://stackoverflow.com/badges/4933/view-scope'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 2819, 'name': 'viewmodel', 'link': 'http://stackoverflow.com/badges/2819/viewmodel'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1145, 'name': 'viewmodel', 'link': 'http://stackoverflow.com/badges/1145/viewmodel'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4779, 'name': 'viewexpiredexception', 'link': 'http://stackoverflow.com/badges/4779/viewexpiredexception'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4568, 'name': 'viewdata', 'link': 'http://stackoverflow.com/badges/4568/viewdata'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2205, 'name': 'viewbag', 'link': 'http://stackoverflow.com/badges/2205/viewbag'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 6, 'badge_id': 1578, 'name': 'view', 'link': 'http://stackoverflow.com/badges/1578/view'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4519, 'name': 'video.js', 'link': 'http://stackoverflow.com/badges/4519/video-js'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5509, 'name': 'video', 'link': 'http://stackoverflow.com/badges/5509/video'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 1015, 'name': 'video', 'link': 'http://stackoverflow.com/badges/1015/video'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5689, 'name': 'vi', 'link': 'http://stackoverflow.com/badges/5689/vi'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 3226, 'name': 'vi', 'link': 'http://stackoverflow.com/badges/3226/vi'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 4, 'badge_id': 3051, 'name': 'vhdl', 'link': 'http://stackoverflow.com/badges/3051/vhdl'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 11, 'badge_id': 1126, 'name': 'vhdl', 'link': 'http://stackoverflow.com/badges/1126/vhdl'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4765, 'name': 'vertical-alignment', 'link': 'http://stackoverflow.com/ba ...
# {'quota_remaining': 9969, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4051, 'name': 'usability', 'link': 'http://stackoverflow.com/badges/4051/usability'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3977, 'name': 'url-routing', 'link': 'http://stackoverflow.com/badges/3977/url-routing'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 3, 'badge_id': 4081, 'name': 'url-rewriting', 'link': 'http://stackoverflow.com/badges/4081/url-rewriting'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 698, 'name': 'url-rewriting', 'link': 'http://stackoverflow.com/badges/698/url-rewriting'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5616, 'name': 'url-pattern', 'link': 'http://stackoverflow.com/badges/5616/url-pattern'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5129, 'name': 'urllib3', 'link': 'http://stackoverflow.com/badges/5129/urllib3'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 1169, 'name': 'urllib2', 'link': 'http://stackoverflow.com/badges/1169/urllib2'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3905, 'name': 'urllib', 'link': 'http://stackoverflow.com/badges/3905/urllib'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 4, 'badge_id': 2360, 'name': 'url', 'link': 'http://stackoverflow.com/badges/2360/url'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 31, 'badge_id': 433, 'name': 'url', 'link': 'http://stackoverflow.com/badges/433/url'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3923, 'name': 'uri', 'link': 'http://stackoverflow.com/badges/3923/uri'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2801, 'name': 'upload', 'link': 'http://stackoverflow.com/badges/2801/upload'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3216, 'name': 'updatepanel', 'link': 'http://stackoverflow.com/badges/3216/updatepanel'}, {'badge_type': 'named', 'rank': 'gold', 'award_count': 14758, 'badge_id': 226, 'name': 'Unsung Hero', 'link': 'http://stackoverflow.com/badges/226/unsung-hero'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3763, 'name': 'unsafe', 'link': 'http://stackoverflow.com/badges/3763/unsafe'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3684, 'name': 'unpivot', 'link': 'http://stackoverflow.com/badges/3684/unpivot'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2643, 'name': 'unpivot', 'link': 'http://stackoverflow.com/badges/2643/unpivot'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3655, 'name': 'unordered-map', 'link': 'http://stackoverflow.com/badges/3655/unordered-map'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2119, 'name': 'unobtrusive-validation', 'link': 'http://stackoverflow.com/badges/2119/unobtrusive-validation'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4513, 'name': 'unmarshalling', 'link': 'http://stackoverflow.com/badges/4513/unmarshalling'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2263, 'name': 'unmarshalling', 'link': 'http://stackoverflow.com/badges/2263/unmarshalling'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1272, 'name': 'unmanaged', 'link': 'http://stackoverflow.com/badges/1272/unmanaged'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 10, 'badge_id': 1878, 'name': 'unix', 'link': 'http://stackoverflow.com/badges/1878/unix'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 32, 'badge_id': 909, 'name': 'unix', 'link': 'http://stackoverflow.com/badges/909/unix'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 188, 'badge_id': 410, 'name': 'u ...
# {'quota_remaining': 9968, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 78, 'badge_id': 491, 'name': 'types', 'link': 'http://stackoverflow.com/badges/491/types'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3451, 'name': 'type-providers', 'link': 'http://stackoverflow.com/badges/3451/type-providers'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 916, 'name': 'type-inference', 'link': 'http://stackoverflow.com/badges/916/type-inference'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6416, 'name': 'type-hinting', 'link': 'http://stackoverflow.com/badges/6416/type-hinting'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3584, 'name': 'typeerror', 'link': 'http://stackoverflow.com/badges/3584/typeerror'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 12, 'badge_id': 1116, 'name': 'typedef', 'link': 'http://stackoverflow.com/badges/1116/typedef'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3401, 'name': 'type-conversion', 'link': 'http://stackoverflow.com/badges/3401/type-conversion'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 6, 'badge_id': 944, 'name': 'type-conversion', 'link': 'http://stackoverflow.com/badges/944/type-conversion'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 1090, 'name': 'typeclass', 'link': 'http://stackoverflow.com/badges/1090/typeclass'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4792, 'name': 'typeahead.js', 'link': 'http://stackoverflow.com/badges/4792/typeahead-js'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2951, 'name': 'tycho', 'link': 'http://stackoverflow.com/badges/2951/tycho'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 3910, 'name': 'twitter-bootstrap-3', 'link': 'http://stackoverflow.com/badges/3910/twitter-bootstrap-3'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 6, 'badge_id': 3524, 'name': 'twitter-bootstrap-3', 'link': 'http://stackoverflow.com/badges/3524/twitter-bootstrap-3'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 22, 'badge_id': 3266, 'name': 'twitter-bootstrap-3', 'link': 'http://stackoverflow.com/badges/3266/twitter-bootstrap-3'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 4, 'badge_id': 3807, 'name': 'twitter-bootstrap', 'link': 'http://stackoverflow.com/badges/3807/twitter-bootstrap'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 22, 'badge_id': 2117, 'name': 'twitter-bootstrap', 'link': 'http://stackoverflow.com/badges/2117/twitter-bootstrap'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 109, 'badge_id': 1809, 'name': 'twitter-bootstrap', 'link': 'http://stackoverflow.com/badges/1809/twitter-bootstrap'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4767, 'name': 'twitter', 'link': 'http://stackoverflow.com/badges/4767/twitter'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 1138, 'name': 'twitter', 'link': 'http://stackoverflow.com/badges/1138/twitter'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4034, 'name': 'twisted.web', 'link': 'http://stackoverflow.com/badges/4034/twisted-web'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 2429, 'name': 'twisted', 'link': 'http://stackoverflow.com/badges/2429/twisted'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 1112, 'name': 'twisted', 'link': 'http://stackoverflow.com/badges/1112/twisted'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 466, 'name': 'twisted', 'link': 'http://stackoverflow.com/badges/466/twisted'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6280, 'name': 'twilio', 'link': 'http:// ...
# {'quota_remaining': 9968, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 7, 'badge_id': 3281, 'name': 'timestamp', 'link': 'http://stackoverflow.com/badges/3281/timestamp'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2475, 'name': 'timespan', 'link': 'http://stackoverflow.com/badges/2475/timespan'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6148, 'name': 'time-series', 'link': 'http://stackoverflow.com/badges/6148/time-series'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 8, 'badge_id': 1949, 'name': 'time-series', 'link': 'http://stackoverflow.com/badges/1949/time-series'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5007, 'name': 'timer', 'link': 'http://stackoverflow.com/badges/5007/timer'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 14, 'badge_id': 1381, 'name': 'timer', 'link': 'http://stackoverflow.com/badges/1381/timer'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5751, 'name': 'time-complexity', 'link': 'http://stackoverflow.com/badges/5751/time-complexity'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 4574, 'name': 'time-complexity', 'link': 'http://stackoverflow.com/badges/4574/time-complexity'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 6, 'badge_id': 2993, 'name': 'time-complexity', 'link': 'http://stackoverflow.com/badges/2993/time-complexity'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 2427, 'name': 'time', 'link': 'http://stackoverflow.com/badges/2427/time'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 16, 'badge_id': 757, 'name': 'time', 'link': 'http://stackoverflow.com/badges/757/time'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4722, 'name': 'tiff', 'link': 'http://stackoverflow.com/badges/4722/tiff'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6428, 'name': 'tidyr', 'link': 'http://stackoverflow.com/badges/6428/tidyr'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 5013, 'name': 'tidyr', 'link': 'http://stackoverflow.com/badges/5013/tidyr'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3308, 'name': 'tidesdk', 'link': 'http://stackoverflow.com/badges/3308/tidesdk'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 5601, 'name': 'thymeleaf', 'link': 'http://stackoverflow.com/badges/5601/thymeleaf'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5953, 'name': 'thrust', 'link': 'http://stackoverflow.com/badges/5953/thrust'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 2734, 'name': 'thrust', 'link': 'http://stackoverflow.com/badges/2734/thrust'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4255, 'name': 'thrift', 'link': 'http://stackoverflow.com/badges/4255/thrift'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3010, 'name': 'three20', 'link': 'http://stackoverflow.com/badges/3010/three20'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 3610, 'name': 'three.js', 'link': 'http://stackoverflow.com/badges/3610/three-js'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 3, 'badge_id': 2776, 'name': 'three.js', 'link': 'http://stackoverflow.com/badges/2776/three-js'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 15, 'badge_id': 2080, 'name': 'three.js', 'link': 'http://stackoverflow.com/badges/2080/three-js'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 1770, 'name': 'thread-safety', 'link': 'http://stackoverflow.com/badges/1770/thread-safety'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 19, 'badge_id': 641, 'name': 'thread-safety', 'link': 'http:// ...
# {'quota_remaining': 9966, 'items': [{'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4844, 'name': 'task', 'link': 'http://stackoverflow.com/badges/4844/task'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 2154, 'name': 'task', 'link': 'http://stackoverflow.com/badges/2154/task'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5366, 'name': 'tar', 'link': 'http://stackoverflow.com/badges/5366/tar'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 1554, 'name': 'tapestry', 'link': 'http://stackoverflow.com/badges/1554/tapestry'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6331, 'name': 'tampermonkey', 'link': 'http://stackoverflow.com/badges/6331/tampermonkey'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4063, 'name': 'tampermonkey', 'link': 'http://stackoverflow.com/badges/4063/tampermonkey'}, {'badge_type': 'named', 'rank': 'bronze', 'award_count': 8293, 'badge_id': 884, 'name': 'Talkative', 'link': 'http://stackoverflow.com/badges/884/talkative'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4750, 'name': 'talend', 'link': 'http://stackoverflow.com/badges/4750/talend'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 4725, 'name': 'tail-recursion', 'link': 'http://stackoverflow.com/badges/4725/tail-recursion'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 1459, 'name': 'tags', 'link': 'http://stackoverflow.com/badges/1459/tags'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4306, 'name': 'taglib', 'link': 'http://stackoverflow.com/badges/4306/taglib'}, {'badge_type': 'named', 'rank': 'bronze', 'award_count': 18757, 'badge_id': 254, 'name': 'Tag Editor', 'link': 'http://stackoverflow.com/badges/254/tag-editor'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3614, 'name': 'tabs', 'link': 'http://stackoverflow.com/badges/3614/tabs'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 4029, 'name': 'tableview', 'link': 'http://stackoverflow.com/badges/4029/tableview'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5376, 'name': 'tablet', 'link': 'http://stackoverflow.com/badges/5376/tablet'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4700, 'name': 'tablesorter', 'link': 'http://stackoverflow.com/badges/4700/tablesorter'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2620, 'name': 'tablesorter', 'link': 'http://stackoverflow.com/badges/2620/tablesorter'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4846, 'name': 'tablemodel', 'link': 'http://stackoverflow.com/badges/4846/tablemodel'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3207, 'name': 'tablecellrenderer', 'link': 'http://stackoverflow.com/badges/3207/tablecellrenderer'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 4325, 'name': 'tablecelleditor', 'link': 'http://stackoverflow.com/badges/4325/tablecelleditor'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5089, 'name': 'tableau', 'link': 'http://stackoverflow.com/badges/5089/tableau'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 17, 'badge_id': 843, 'name': 'table', 'link': 'http://stackoverflow.com/badges/843/table'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2058, 'name': 'tabcontrol', 'link': 'http://stackoverflow.com/badges/2058/tabcontrol'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1652, 'name': 't4mvc', 'link': 'http://stackoverflow.com/badges/1652/t4mvc'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 1028, 'name': 't4', 'link': 'http: ...
# {'quota_remaining': 9965, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3526, 'name': 'sugarcrm', 'link': 'http://stackoverflow.com/badges/3526/sugarcrm'}, {'badge_type': 'named', 'rank': 'bronze', 'award_count': 34007, 'badge_id': 804, 'name': 'Suffrage', 'link': 'http://stackoverflow.com/badges/804/suffrage'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 2980, 'name': 'substring', 'link': 'http://stackoverflow.com/badges/2980/substring'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 463, 'name': 'subsonic3', 'link': 'http://stackoverflow.com/badges/463/subsonic3'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 442, 'name': 'subsonic', 'link': 'http://stackoverflow.com/badges/442/subsonic'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 159, 'name': 'subsonic', 'link': 'http://stackoverflow.com/badges/159/subsonic'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6106, 'name': 'subset', 'link': 'http://stackoverflow.com/badges/6106/subset'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 3764, 'name': 'subset', 'link': 'http://stackoverflow.com/badges/3764/subset'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 4576, 'name': 'subroutine', 'link': 'http://stackoverflow.com/badges/4576/subroutine'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5416, 'name': 'subquery', 'link': 'http://stackoverflow.com/badges/5416/subquery'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 1635, 'name': 'subquery', 'link': 'http://stackoverflow.com/badges/1635/subquery'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5108, 'name': 'subprocess', 'link': 'http://stackoverflow.com/badges/5108/subprocess'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3466, 'name': 'subprocess', 'link': 'http://stackoverflow.com/badges/3466/subprocess'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 925, 'name': 'subprocess', 'link': 'http://stackoverflow.com/badges/925/subprocess'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5249, 'name': 'sublime-text-plugin', 'link': 'http://stackoverflow.com/badges/5249/sublime-text-plugin'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5093, 'name': 'sublimetext3', 'link': 'http://stackoverflow.com/badges/5093/sublimetext3'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4336, 'name': 'sublimetext3', 'link': 'http://stackoverflow.com/badges/4336/sublimetext3'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3645, 'name': 'sublimetext3', 'link': 'http://stackoverflow.com/badges/3645/sublimetext3'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5644, 'name': 'sublimetext2', 'link': 'http://stackoverflow.com/badges/5644/sublimetext2'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 3, 'badge_id': 4139, 'name': 'sublimetext2', 'link': 'http://stackoverflow.com/badges/4139/sublimetext2'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 10, 'badge_id': 2739, 'name': 'sublimetext2', 'link': 'http://stackoverflow.com/badges/2739/sublimetext2'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5251, 'name': 'sublimetext', 'link': 'http://stackoverflow.com/badges/5251/sublimetext'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4373, 'name': 'sublimetext', 'link': 'http://stackoverflow.com/badges/4373/sublimetext'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 8, 'badge_id': 2289, 'name': 'sublimetext', 'link': 'http://stackoverflow.com/badges/2289/sublimetext'}, {'badge_type': 'tag_based', 'rank': 'br ...
# {'quota_remaining': 9962, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6218, 'name': 'ssrs-grouping', 'link': 'http://stackoverflow.com/badges/6218/ssrs-grouping'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 4879, 'name': 'ssrs-2008', 'link': 'http://stackoverflow.com/badges/4879/ssrs-2008'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 1865, 'name': 'ssrs-2008', 'link': 'http://stackoverflow.com/badges/1865/ssrs-2008'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 7, 'badge_id': 1653, 'name': 'ssms', 'link': 'http://stackoverflow.com/badges/1653/ssms'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5997, 'name': 'ssl-certificate', 'link': 'http://stackoverflow.com/badges/5997/ssl-certificate'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 2326, 'name': 'ssl-certificate', 'link': 'http://stackoverflow.com/badges/2326/ssl-certificate'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 2834, 'name': 'ssl', 'link': 'http://stackoverflow.com/badges/2834/ssl'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 6, 'badge_id': 1877, 'name': 'ssl', 'link': 'http://stackoverflow.com/badges/1877/ssl'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 24, 'badge_id': 571, 'name': 'ssl', 'link': 'http://stackoverflow.com/badges/571/ssl'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 3506, 'name': 'ssis', 'link': 'http://stackoverflow.com/badges/3506/ssis'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 1969, 'name': 'ssis', 'link': 'http://stackoverflow.com/badges/1969/ssis'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 14, 'badge_id': 1251, 'name': 'ssis', 'link': 'http://stackoverflow.com/badges/1251/ssis'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4002, 'name': 'ssh-keys', 'link': 'http://stackoverflow.com/badges/4002/ssh-keys'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 6285, 'name': 'ssh', 'link': 'http://stackoverflow.com/badges/6285/ssh'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3986, 'name': 'ssh', 'link': 'http://stackoverflow.com/badges/3986/ssh'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 15, 'badge_id': 2248, 'name': 'ssh', 'link': 'http://stackoverflow.com/badges/2248/ssh'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3057, 'name': 'sse2', 'link': 'http://stackoverflow.com/badges/3057/sse2'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 5507, 'name': 'sse', 'link': 'http://stackoverflow.com/badges/5507/sse'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 2715, 'name': 'sse', 'link': 'http://stackoverflow.com/badges/2715/sse'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 8, 'badge_id': 1232, 'name': 'sse', 'link': 'http://stackoverflow.com/badges/1232/sse'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 5275, 'name': 'ssdt', 'link': 'http://stackoverflow.com/badges/5275/ssdt'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5634, 'name': 'sscanf', 'link': 'http://stackoverflow.com/badges/5634/sscanf'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 6, 'badge_id': 3671, 'name': 'ssas', 'link': 'http://stackoverflow.com/badges/3671/ssas'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 2253, 'name': 'squeak', 'link': 'http://stackoverflow.com/badges/2253/squeak'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 3542, 'name': 'sqlxml', 'link': 'http://stackoverflow.com/badges/3542/sqlxml'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 4248, 'name ...
# ...
# {'quota_remaining': 9930, 'items': [{'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 6339, 'name': 'facebook-friends', 'link': 'http://stackoverflow.com/badges/6339/facebook-friends'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3631, 'name': 'facebook-fql', 'link': 'http://stackoverflow.com/badges/3631/facebook-fql'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 1850, 'name': 'facebook-c#-sdk', 'link': 'http://stackoverflow.com/badges/1850/facebook-c-sdk'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5160, 'name': 'facebook-apps', 'link': 'http://stackoverflow.com/badges/5160/facebook-apps'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3519, 'name': 'facebook-android-sdk', 'link': 'http://stackoverflow.com/badges/3519/facebook-android-sdk'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4817, 'name': 'facebook-access-token', 'link': 'http://stackoverflow.com/badges/4817/facebook-access-token'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 7, 'badge_id': 2336, 'name': 'facebook', 'link': 'http://stackoverflow.com/badges/2336/facebook'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 19, 'badge_id': 1309, 'name': 'facebook', 'link': 'http://stackoverflow.com/badges/1309/facebook'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 73, 'badge_id': 553, 'name': 'facebook', 'link': 'http://stackoverflow.com/badges/553/facebook'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 4, 'badge_id': 3358, 'name': 'fabricjs', 'link': 'http://stackoverflow.com/badges/3358/fabricjs'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 3125, 'name': 'fabric', 'link': 'http://stackoverflow.com/badges/3125/fabric'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1800, 'name': 'f#-interactive', 'link': 'http://stackoverflow.com/badges/1800/f-interactive'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5406, 'name': 'f#-data', 'link': 'http://stackoverflow.com/badges/5406/f-data'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 5713, 'name': 'f#-3.0', 'link': 'http://stackoverflow.com/badges/5713/f-3-0'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 81, 'badge_id': 444, 'name': 'f#', 'link': 'http://stackoverflow.com/badges/444/f'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 9, 'badge_id': 152, 'name': 'f#', 'link': 'http://stackoverflow.com/badges/152/f'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 24, 'badge_id': 74, 'name': 'f#', 'link': 'http://stackoverflow.com/badges/74/f'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 2656, 'name': 'extjs4.1', 'link': 'http://stackoverflow.com/badges/2656/extjs4-1'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 2897, 'name': 'extjs4', 'link': 'http://stackoverflow.com/badges/2897/extjs4'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 17, 'badge_id': 1538, 'name': 'extjs4', 'link': 'http://stackoverflow.com/badges/1538/extjs4'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 1, 'badge_id': 4647, 'name': 'extjs', 'link': 'http://stackoverflow.com/badges/4647/extjs'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 10, 'badge_id': 1277, 'name': 'extjs', 'link': 'http://stackoverflow.com/badges/1277/extjs'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 58, 'badge_id': 656, 'name': 'extjs', 'link': 'http://stackoverflow.com/badges/656/extjs'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 9, 'badge_id': 469, 'name': 'extension-methods', 'link': 'http://stackoverflow.com/badges/469/extension-methods'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 2, 'badge_id': 214, 'name': ...
# {'backoff': 10, 'quota_remaining': 9930, 'items': [{'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 1406, 'name': 'entity-framework-4.1', 'link': 'http://stackoverflow.com/badges/1406/entity-framework-4-1'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 3, 'badge_id': 1139, 'name': 'entity-framework-4.1', 'link': 'http://stackoverflow.com/badges/1139/entity-framework-4-1'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 5, 'badge_id': 1051, 'name': 'entity-framework-4.1', 'link': 'http://stackoverflow.com/badges/1051/entity-framework-4-1'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 1447, 'name': 'entity-framework-4', 'link': 'http://stackoverflow.com/badges/1447/entity-framework-4'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 5, 'badge_id': 1064, 'name': 'entity-framework-4', 'link': 'http://stackoverflow.com/badges/1064/entity-framework-4'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 16, 'badge_id': 807, 'name': 'entity-framework-4', 'link': 'http://stackoverflow.com/badges/807/entity-framework-4'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 9, 'badge_id': 987, 'name': 'entity-framework', 'link': 'http://stackoverflow.com/badges/987/entity-framework'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 157, 'badge_id': 299, 'name': 'entity-framework', 'link': 'http://stackoverflow.com/badges/299/entity-framework'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 33, 'badge_id': 171, 'name': 'entity-framework', 'link': 'http://stackoverflow.com/badges/171/entity-framework'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 1876, 'name': 'entity-attribute-value', 'link': 'http://stackoverflow.com/badges/1876/entity-attribute-value'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 3809, 'name': 'entity', 'link': 'http://stackoverflow.com/badges/3809/entity'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 2, 'badge_id': 1548, 'name': 'entity', 'link': 'http://stackoverflow.com/badges/1548/entity'}, {'badge_type': 'named', 'rank': 'silver', 'award_count': 137832, 'badge_id': 71, 'name': 'Enthusiast', 'link': 'http://stackoverflow.com/badges/71/enthusiast'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4622, 'name': 'enthought', 'link': 'http://stackoverflow.com/badges/4622/enthought'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 5005, 'name': 'enterprise-library', 'link': 'http://stackoverflow.com/badges/5005/enterprise-library'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 1161, 'name': 'enterprise-library', 'link': 'http://stackoverflow.com/badges/1161/enterprise-library'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 3, 'badge_id': 3210, 'name': 'enterprise-architect', 'link': 'http://stackoverflow.com/badges/3210/enterprise-architect'}, {'badge_type': 'named', 'rank': 'silver', 'award_count': 251189, 'badge_id': 19, 'name': 'Enlightened', 'link': 'http://stackoverflow.com/badges/19/enlightened'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 1, 'badge_id': 6435, 'name': 'end-to-end', 'link': 'http://stackoverflow.com/badges/6435/end-to-end'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 1, 'badge_id': 4882, 'name': 'end-to-end', 'link': 'http://stackoverflow.com/badges/4882/end-to-end'}, {'badge_type': 'tag_based', 'rank': 'gold', 'award_count': 2, 'badge_id': 4641, 'name': 'encryption', 'link': 'http://stackoverflow.com/badges/4641/encryption'}, {'badge_type': 'tag_based', 'rank': 'silver', 'award_count': 8, 'badge_id': 951, 'name': 'encryption', 'link': 'http://stackoverflow.com/badges/951/encryption'}, {'badge_type': 'tag_based', 'rank': 'bronze', 'award_count': 46, 'badge_id': 532, 'name': 'encryption', 'link': 'http://stackoverflow.com/badges/532/encrypti ...
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}
# {'error_name': 'throttle_violation', 'error_message': 'Violation of backoff parameter', 'error_id': 502}

# %% [markdown]
# # Gathering data for questions

# %%
path1 = 'Questions'
if not os.path.exists(path1):
    os.makedirs(path1)


for i in range(1,301):        
    url1 = 'https://api.stackexchange.com/2.2/questions?page='+str(i)+'&pagesize=100&order=desc&sort=activity&site=stackoverflow&key=IwwP2VRDlnaZ82DdajaXFQ(('
    response1 = requests.get(url1)
    response1 = response1.json()
    sleep(2)
    #print(response1)
    with open('Questions/'+str(i)+'.json', 'w') as f:
         json.dump(response1, f)

# %% [markdown]
# # ANALYSIS 1: Top 5 users who have the maximum reputation on Java topic

# %%
json_files_path = "C:/PYTHON/Lecture-06/Questions"

present_dict = {}
cust_segments_dict = {}

json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]
#type(json_files)
#print(json_files)
questions = {}
user_reputation = 0
user = {}
owner ={}
text = []

for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            
            for items in json_dict['items']:
                try:
                     for i in items['tags']:
                            if i == 'java':
                                #print("found")
                                if items['owner']['reputation'] is not None:
                                    user[items['owner']['user_id']] = items['owner']['reputation']
                                    text.append(items['owner']['user_id'])
                                    
                #questions[items['question_id']] = items
                #text.append(questions)
                except KeyError:
                    continue
#newA = dict(sorted(user.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])  

top5 = sorted(user, key=user.get, reverse=True)[:5]
#print(newA)

#import csv
#with open('users.csv', 'w') as csv_file:
    #writer = csv.writer(csv_file)
    #for key, value in user.items():
           #writer.writerow([key, value])
    #writer.writeheader()

        
        
#print(len(text))
#print(top5)
#type(text[0])

# %%
json_files_path = "C:/PYTHON/Lecture-06/Users"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]

reputedNames =[]
print("Top 5 Most reputed users for tag Java are as follows:")
for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            #print("Top 5 Most reputed users for Java are as follows:")
            for i in top5:
                for items in json_dict['items']:
                    try:
                        if items['user_id'] is not None:
                            if items['user_id'] == i:  
                                print("User Id" , str(i) +" & Name:", items['display_name'])
                                reputedNames.append(items['display_name'])
                                
                    except KeyError:
                        continue

                        
import csv                        
def WriteDictToCSV(csv_file,csv_columns,dict_data):
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
            print("I/O error({0}): {1}".format(errno, strerror))    
    return            

csv_columns = ['Row','UserId','Name']
dict_data = [
    {'Row': 1, 'UserId': top5[0], 'Name': reputedNames[0]},
    {'Row': 2, 'UserId': top5[1], 'Name': reputedNames[1]},
    {'Row': 3, 'UserId': top5[2], 'Name': reputedNames[2]},
    {'Row': 4, 'UserId': top5[3], 'Name': reputedNames[3]},
    {'Row': 5, 'UserId': top5[4], 'Name': reputedNames[4]},
    ]

currentPath = os.getcwd()
csv_file = "Top5ReputedUserJava.csv"

WriteDictToCSV(csv_file,csv_columns,dict_data)
# Out:
# Top 5 Most reputed users for tag Java are as follows:
# User Id 34088 & Name: Aaron Digulla
# User Id 276101 & Name: polygenelubricants
# User Id 44330 & Name: Jason S
# User Id 829571 & Name: assylias
# User Id 1103872 & Name: Marko Topolnik

# %% [markdown]
# # Writing User Ids to a text file

# %%
user_text = open('users.txt', 'w')
                
for item in text:
    user_text.write("%s\n" % item)
    
user_text.close()

# %% [markdown]
# # Gathering data for privileges

# %%
path2 = 'Privileges'

if not os.path.exists(path2):
    os.makedirs(path2)


    i=1    
    url2 = 'https://api.stackexchange.com/2.2/privileges?page='+str(i)+'&pagesize=100&site=stackoverflow&key=IwwP2VRDlnaZ82DdajaXFQ(('
    response2 = requests.get(url2)
    response2 = response2.json()
    #print(response1)
    with open('Privileges/'+str(i)+'.json', 'w') as f:
         json.dump(response2, f)

# %% [markdown]
# # Gathering User profile data from questions/ids by passing userids

# %%
path3 = 'Users'
if not os.path.exists(path3):
    os.makedirs(path3)

a = text[2501:4001]
    
count=2500
for i in a:
    count += 1
    user_url = 'https://api.stackexchange.com/2.2/users/'+str(i)+'?site=stackoverflow&key=IwwP2VRDlnaZ82DdajaXFQ(('                 #+'?page='+str(count)+'&pagesize=100&order=desc&sort=reputation&site=stackoverflow&key=IwwP2VRDlnaZ82DdajaXFQ(('
    user_response = requests.get(user_url)
    #sleep()
    user_response = user_response.json()
    #print(response1)
        
    with open('Users/'+str(count)+'.json', 'w') as f:
         json.dump(user_response, f)

#print(user_response)

# %% [markdown]
# # ANALYSIS 2: Badges Percentage Distribution

# %%
json_files_path = "C:/PYTHON/Lecture-06/Users"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]
bronze = []
silver = []
gold = []

for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            
            for items in json_dict['items']:
                try:
                    if items['badge_counts']['bronze'] is not None:
                        bronze.append(items['badge_counts']['bronze'])
                    
                    if items['badge_counts']['silver'] is not None:
                        silver.append(items['badge_counts']['silver'])
                        
                    if items['badge_counts']['gold'] is not None:
                        gold.append(items['badge_counts']['gold'])    
                except KeyError:
                    continue
#newA = dict(sorted(user.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])  

#sorted(user, key=user.get, reverse=True)[:5]
#print(newA)
#import csv
#with open('dict.csv', 'wb') as csv_file:
    #writer = csv.writer(csv_file)
    #for key, value in user.items():
           #writer.writerow([key, value])

count_total_number_badges =0       
count_total_bronze_badges = 0
count_total_silver_badges = 0
count_total_gold_badges = 0
for i in bronze:
    count_total_bronze_badges += i
for i in silver:
    count_total_silver_badges += i
for i in gold:
    count_total_gold_badges += i

count_total_number_badges = count_total_bronze_badges + count_total_silver_badges + count_total_gold_badges

#print(count_total_bronze_badges)
#print(count_total_silver_badges)
#print(count_total_gold_badges)
#print(count_total_number_badges)



import csv                        
def WriteDictToCSV(csv_file,csv_columns,dict_data):
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
            print("I/O error({0}): {1}".format(errno, strerror))    
    return            

csv_columns = ['Row','Badges','Percentage']
dict_data = [
    {'Row': 1, 'Badges': "Gold", 'Percentage': (count_total_gold_badges/count_total_number_badges)*100},
    {'Row': 2, 'Badges': "Silver", 'Percentage': (count_total_silver_badges/count_total_number_badges)*100},
    {'Row': 3, 'Badges': "Bronze", 'Percentage': (count_total_bronze_badges/count_total_number_badges)*100},
    
    ]

currentPath = os.getcwd()
csv_file = "BadgesPercentage.csv"

WriteDictToCSV(csv_file,csv_columns,dict_data)





print("Percentage of gold badges   :", (count_total_gold_badges/count_total_number_badges)*100)
print("Percentage of silver badges :", (count_total_silver_badges/count_total_number_badges)*100)
print("Percentage of bronze badges :", (count_total_bronze_badges/count_total_number_badges)*100)
# Out:
# Percentage of gold badges   : 6.306732970242324
# Percentage of silver badges : 27.92643460415187
# Percentage of bronze badges : 65.76683242560581

# %% [markdown]
# # ANALYSIS 3: Privileges percentage of users on Stackoverflow.com

# %%
json_files_path = "C:/PYTHON/Lecture-06/Questions"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]
#type(json_files)
#print(json_files)
text = []
privilege_access_site_analytics = 0
privilege_access_moderator_tools = 0
privilege_access_trusted_user = 0
privilege_access_create_chat_rooms = 0
privilege_access_below_100_reputation = 0


for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            
            for items in json_dict['items']:
                try:
                    if items['owner']['reputation'] is not None:
                        user[items['owner']['user_id']] = items['owner']['reputation']
                        text.append(items['owner']['user_id'])
                    
                    if ((items['owner']['reputation']) >= 25000):
                            privilege_access_site_analytics += 1
                    if ((items['owner']['reputation']) >=20000):
                            privilege_access_trusted_user += 1
                    if ((items['owner']['reputation']) >=10000):
                            privilege_access_moderator_tools += 1
                    if ((items['owner']['reputation']) >= 100):
                            privilege_access_create_chat_rooms += 1
                    if ((items['owner']['reputation']) < 100):
                            privilege_access_below_100_reputation += 1
                                    
                #questions[items['question_id']] = items
                #text.append(questions)
                except KeyError:
                    continue

privilege_access_below_100 = (privilege_access_below_100_reputation - 1507)


print((privilege_access_site_analytics/len(text)) *100, "% of users on Stackoverflow.com have access to internal & Google site analytics")
print((privilege_access_trusted_user/len(text)) *100, "% of users on Stackoverflow.com are trusted users who have access to expanded editing, deletion & undeletion privileges")
print((privilege_access_moderator_tools/len(text)) *100, "% of users on Stackoverflow.com have access to moderator tools & can access reports, delete questions & review reviews")
print((privilege_access_create_chat_rooms/len(text)) *100, "% of users on Stackoverflow.com have access to create new chat rooms")
print((privilege_access_below_100/len(text)) *100, "% of users on Stackoverflow.com have reputation less than 100")


import csv                        
def WriteDictToCSV(csv_file,csv_columns,dict_data):
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
            print("I/O error({0}): {1}".format(errno, strerror))    
    return            

csv_columns = ['Row','Privilege','Percentage']
dict_data = [
    {'Row': 1, 'Privilege': "Access to site Analytics", 'Percentage': (privilege_access_site_analytics/len(text)) *100},
    {'Row': 2, 'Privilege': "Trusted Users", 'Percentage': (privilege_access_trusted_user/len(text)) *100},
    {'Row': 3, 'Privilege': "Access to moderate tools", 'Percentage': (privilege_access_moderator_tools/len(text)) *100},
    {'Row': 4, 'Privilege': "Create New Chat Rooms", 'Percentage': (privilege_access_create_chat_rooms/len(text)) *100},
    {'Row': 5, 'Privilege': "Reputation less than 100", 'Percentage': (privilege_access_below_100/len(text)) *100},
    
    ]

currentPath = os.getcwd()
csv_file = "PrivilegesPercentage.csv"

WriteDictToCSV(csv_file,csv_columns,dict_data)
# Out:
# 0.9659736613409988 % of users on Stackoverflow.com have access to internal & Google site analytics
# 1.3002206029814827 % of users on Stackoverflow.com are trusted users who have access to expanded editing, deletion & undeletion privileges
# 2.770907146199612 % of users on Stackoverflow.com have access to moderator tools & can access reports, delete questions & review reviews
# 40.34026338659002 % of users on Stackoverflow.com have access to create new chat rooms
# 54.62263520288789 % of users on Stackoverflow.com have reputation less than 100

# %% [markdown]
# # ANALYSIS 4 : Age Group of Users

# %%
json_files_path = "C:/PYTHON/Lecture-06/Users"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]

age_60_and_above = 0
age_40_and_below_60 = 0
age_30_and_below_40 = 0
age_20_and_below_30 = 0
age_below_20 = 0
people_below_1000_reputation = 0
for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            
            for items in json_dict['items']:
                try:
                    if items['age'] is not None and items['reputation'] is not None:
                        if((items['age']) >= 60 and (items['reputation'] >=1000)):
                            age_60_and_above +=1
                        elif((items['age']) >= 40 and (items['age']) < 60 and (items['reputation'] >=1000)):
                            age_40_and_below_60 +=1
                        elif((items['age']) >= 30 and (items['age']) < 40 and (items['reputation'] >=1000)):
                            age_30_and_below_40 +=1
                        elif((items['age']) >= 20 and (items['age']) < 30 and (items['reputation'] >=1000)):
                            age_20_and_below_30 +=1
                        elif((items['age']) < 20):
                            age_below_20 +=1
                        else:
                            people_below_1000_reputation +=1 
        
                except KeyError:
                    continue
total_people = (age_below_20 + age_20_and_below_30 + age_30_and_below_40 + age_40_and_below_60 + age_60_and_above)                    
#print(people_below_1000_reputation)
print("Percentage of Senior Users using stackoverflow.com & with reputation more than 1000 is :", (age_60_and_above/total_people)*100)
print("Percentage of Very Experienced Users using stackoverflow.com & with reputation more than 1000 is :", (age_40_and_below_60/total_people)*100)
print("Percentage of Experienced Users using stackoverflow.com & with reputation more than 1000 is :", (age_30_and_below_40/total_people)*100)
print("Percentage of Young Users using stackoverflow.com & with reputation more than 1000 is :", (age_20_and_below_30/total_people)*100)
print("Percentage of New & Highly Active Users using stackoverflow.com is :", (age_below_20/total_people)*100)




import csv                        
def WriteDictToCSV(csv_file,csv_columns,dict_data):
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
            print("I/O error({0}): {1}".format(errno, strerror))    
    return            

csv_columns = ['Row','Age','Percentage']
dict_data = [
    {'Row': 1, 'Age': "Senior Users", 'Percentage': (age_60_and_above/total_people)*100},
    {'Row': 2, 'Age': "Very Experienced Users", 'Percentage': (age_40_and_below_60/total_people)*100},
    {'Row': 3, 'Age': "Experienced Users", 'Percentage': (age_30_and_below_40/total_people)*100},
    {'Row': 4, 'Age': "Young Users", 'Percentage': (age_20_and_below_30/total_people)*100},
    {'Row': 5, 'Age': "New & Highly Active Users", 'Percentage': (age_below_20/total_people)*100},
    
    ]

currentPath = os.getcwd()
csv_file = "AgeGroupPercentage.csv"

WriteDictToCSV(csv_file,csv_columns,dict_data)
# Out:
# Percentage of Senior Users using stackoverflow.com & with reputation more than 1000 is : 1.4354066985645932
# Percentage of Very Experienced Users using stackoverflow.com & with reputation more than 1000 is : 9.090909090909092
# Percentage of Experienced Users using stackoverflow.com & with reputation more than 1000 is : 38.75598086124402
# Percentage of Young Users using stackoverflow.com & with reputation more than 1000 is : 30.14354066985646
# Percentage of New & Highly Active Users using stackoverflow.com is : 20.574162679425836

# %%
json_files_path = "C:/PYTHON/Lecture-06/Users"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]

print("Top 5 Most reputed users for tag Java are as follows:")
for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            #print("Top 5 Most reputed users for Java are as follows:")
            for i in top5:
                for items in json_dict['items']:
                    try:
                        if items['user_id'] is not None:
                            if items['user_id'] == i:  
                                print("User Id" , str(i) +" & Name:", items['display_name'])
                    except KeyError:
                        continue
# Out:
# Top 5 Most reputed users for tag Java are as follows:
# User Id 34088 & Name: Aaron Digulla
# User Id 276101 & Name: polygenelubricants
# User Id 44330 & Name: Jason S
# User Id 829571 & Name: assylias
# User Id 1103872 & Name: Marko Topolnik

# %% [markdown]
# # ANALYSIS 5 : TOP 10 QUESTIONS VIEWED THE MOST

# %%
json_files_path = "C:/PYTHON/Lecture-06/Questions"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]
#type(json_files)
#print(json_files)
text = []
top_viewed_questions = {}
for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            
            for items in json_dict['items']:
                try:
                    if items['view_count'] is not None:
                        top_viewed_questions[items['owner']['user_id']] = items['view_count']
                        text.append(items['owner']['user_id'])                     
                #questions[items['question_id']] = items
                #text.append(questions)
                except KeyError:
                    continue
                    
#newA = dict(sorted(user.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])  
#print(top_viewed_questions)
#top10views = sorted(top_viewed_questions, key=top_viewed_questions.get, reverse=True)[:10]

#print(top10views)
#print(newA)
#import csv
#with open('dict.csv', 'wb') as csv_file:
    #writer = csv.writer(csv_file)
    #for key, value in user.items():
           #writer.writerow([key, value])
# Out:
# [44984, 111435, 173432, 8018, 17085, 508284, 21709, 3713, 206504, 4883]

# %%
json_files_path = "C:/PYTHON/Lecture-06/Questions"
json_files = [json_pos for json_pos in os.listdir(json_files_path) if json_pos.endswith('.json')]
topQuestions = []

print("Top 10 Most viewed questions are as follows:")
for js in json_files:
    full_filename = js.split('.json')
    with open(os.path.join(json_files_path, js)) as one_json_file:
        for line in one_json_file.readlines():
            json_dict = json.loads(line);
            #print(type(json_dict))
            #print("Top 5 Most reputed users for Java are as follows:")
            for i in top10views:
                for items in json_dict['items']:
                    try:
                        if items['owner']['user_id'] is not None:
                            if items['owner']['user_id'] == i:  
                                print("User Id" , str(i) +" & Question:", items['title'])
                                topQuestions.append(items['title'])
                    except KeyError:
                        continue
                        
import csv                        
def WriteDictToCSV(csv_file,csv_columns,dict_data):
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
            print("I/O error({0}): {1}".format(errno, strerror))    
    return            

csv_columns = ['Row','UserId','Question']
dict_data = [
    {'Row': 1, 'UserId': top10views[0], 'Question': topQuestions[0]},
    {'Row': 2, 'UserId': top10views[1], 'Question': topQuestions[0]},
    {'Row': 3, 'UserId': top10views[2], 'Question': topQuestions[0]},
    {'Row': 4, 'UserId': top10views[3], 'Question': topQuestions[0]},
    {'Row': 5, 'UserId': top10views[4], 'Question': topQuestions[0]},
    {'Row': 6, 'UserId': top10views[5], 'Question': topQuestions[0]},
    {'Row': 7, 'UserId': top10views[6], 'Question': topQuestions[0]},
    {'Row': 8, 'UserId': top10views[7], 'Question': topQuestions[0]},
    {'Row': 9, 'UserId': top10views[8], 'Question': topQuestions[0]},
    {'Row': 10,'UserId': top10views[9], 'Question': topQuestions[0]},
    
    ]

currentPath = os.getcwd()
csv_file = "Top10QuestionsViewed.csv"

WriteDictToCSV(csv_file,csv_columns,dict_data)
# Out:
# Top 10 Most viewed questions are as follows:
# User Id 111435 & Question: How do I check if a checkbox is checked in jQuery?
# User Id 44984 & Question: How do I redirect to another page in jQuery?
# User Id 21709 & Question: How do I check if an element is hidden in jQuery?
# User Id 4883 & Question: How do I discard unstaged changes in Git?
# User Id 173432 & Question: Redirect from an HTML page?
# User Id 8018 & Question: Which &quot;href&quot; value to use for JavaScript links: &quot;#&quot; or &quot;javascript:void(0)&quot;?
# User Id 3713 & Question: How to resolve merge conflicts in Git?
# User Id 508284 & Question: How to vertically center text with CSS?
# User Id 17085 & Question: Calling an external command in Python
# User Id 206504 & Question: How to get the size of a list

# %%
import csv
with open('dict.csv', 'wb') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in mydict.items():
           writer.writerow([key, value])
